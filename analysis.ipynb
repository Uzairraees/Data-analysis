# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/archive (1)/netflix_titles.csv")
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())
# Out:
#     show_id     type                             title director  \
# 1  80117401    Movie        Jandino: Whatever it Takes      NaN
# 2  70234439  TV Show                Transformers Prime      NaN
# 3  80058654  TV Show  Transformers: Robots in Disguise      NaN
# 5  80163890  TV Show                           Apaches      NaN
# 8  80117902  TV Show                      Fire Chasers      NaN
#
#                                                 cast         country  \
# 1                                   Jandino Asporaat  United Kingdom
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...   United States
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...   United States
# 5  Alberto Ammann, Eloy Azorín, Verónica Echegui,...           Spain
# 8                                                NaN   United States
#
#           date_added  release_year    rating  duration  \
# 1  September 9, 2016          2016     TV-MA    94 min
# ...

# %%
df = df.dropna(how='all')
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())
# Out:
#     show_id     type                             title director  \
# 1  80117401    Movie        Jandino: Whatever it Takes      NaN
# 2  70234439  TV Show                Transformers Prime      NaN
# 3  80058654  TV Show  Transformers: Robots in Disguise      NaN
# 5  80163890  TV Show                           Apaches      NaN
# 8  80117902  TV Show                      Fire Chasers      NaN
#
#                                                 cast         country  \
# 1                                   Jandino Asporaat  United Kingdom
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...   United States
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...   United States
# 5  Alberto Ammann, Eloy Azorín, Verónica Echegui,...           Spain
# 8                                                NaN   United States
#
#           date_added  release_year    rating  duration  \
# 1  September 9, 2016          2016     TV-MA    94 min
# ...

# %%
df = df.dropna(axis=0)

# %%
df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
df.nunique()
# Out:
# show_id         3774
# type               2
# title           3752
# director        2920
# cast            3667
# country          433
# date_added      1014
# release_year      69
# rating            14
# duration         184
# listed_in        296
# description     3766
# dtype: int64

# %%
df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 0 to 6213
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3774 non-null   int64
#  1   type          3774 non-null   object
#  2   title         3774 non-null   object
#  3   director      3774 non-null   object
#  4   cast          3774 non-null   object
#  5   country       3774 non-null   object
#  6   date_added    3774 non-null   object
#  7   release_year  3774 non-null   int64
#  8   rating        3774 non-null   object
#  9   duration      3774 non-null   object
#  10  listed_in     3774 non-null   object
#  11  description   3774 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 383.3+ KB

# %%
df.shape
# Out:
# (3774, 12)

# %%
df["type"].value_counts()
# Out:
# Movie      3678
# TV Show      96
# Name: type, dtype: int64

# %%
df.groupby('type')['show_id'].count()
# Out:
# type
# Movie      3678
# TV Show      96
# Name: show_id, dtype: int64

# %%
df.loc[:,'release_year']
# Out:
# 0       2019
# 4       2017
# 6       2014
# 7       2017
# 9       2014
#         ...
# 6142    2019
# 6158    2018
# 6167    2019
# 6182    2019
# 6213    2014
# Name: release_year, Length: 3774, dtype: int64

# %%
df.loc[:,['release_year','duration']]
# Out:
#       release_year   duration
# 0             2019     90 min
# 4             2017     99 min
# 6             2014    110 min
# 7             2017     60 min
# 9             2014     90 min
# ...            ...        ...
# 6142          2019  7 Seasons
# 6158          2018  4 Seasons
# 6167          2019  2 Seasons
# 6182          2019  4 Seasons
# 6213          2014  3 Seasons
#
# [3774 rows x 2 columns]

# %%
sample_size=2

unique_countries =(df)

sample= random.sample(unique_countries, sample_size)

top_n_ratings=2

for country in sample:
    plot_most_popular_ratings(country, top_n_ratings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4e068ad90050> in <module>
#       1 sample_size=2
#       2
# ----> 3 unique_countries =get_unique_countries(df)
#       4
#       5 sample= random.sample(unique_countries, sample_size)
#
# NameError: name 'get_unique_countries' is not defined

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.iloc[[2,3,105]]
# Out:
#       show_id   type                               title  \
# 6    70304989  Movie                            Automata
# 7    80164077  Movie  Fabrizio Copano: Solo pienso en mi
# 191  80987075  Movie                          Class Rank
#
#                             director  \
# 6                        Gabe Ibáñez
# 7    Rodrigo Toro, Francisco Schultz
# 191                      Eric Stoltz
#
#                                                   cast  \
# 6    Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                      Fabrizio Copano
# 191  Olivia Holt, Skyler Gisondo, Kristin Chenoweth...
#
#                                     country          date_added  release_year  \
# 6    Bulgaria, United States, Spain, Canada   September 8, 2017          2014
# 7                                     Chile   September 8, 2017          2017
# 191                           United States  September 18, 2018          2018
#
# ...

# %%
(df['type'].value_counts().head(5) / len(df)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['release_year'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
recommendation('Friends')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-cfc6f16999f5> in <module>
# ----> 1 recommendation('Friends')
#
# NameError: name 'recommendation' is not defined

# %%
df['country'].value_counts()
# Out:
# United States                                   1323
# India                                            707
# United Kingdom                                   152
# Canada                                            78
# Spain                                             72
#                                                 ...
# United States, France, Italy, United Kingdom       1
# Mexico, Finland                                    1
# United Kingdom, New Zealand                        1
# United States, France, Canada, Spain               1
# United Kingdom, India, United States               1
# Name: country, Length: 433, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# TV-MA       1189
# TV-14        917
# R            501
# TV-PG        358
# PG-13        278
# PG           176
# NR           175
# TV-G          54
# TV-Y7         48
# G             35
# TV-Y          24
# TV-Y7-FV      11
# UR             7
# NC-17          1
# Name: rating, dtype: int64

# %%
top_listed_in=df["listed_in"].value_counts()[0:25]
top_listed_in.head()
# Out:
# Dramas, International Movies                        237
# Stand-Up Comedy                                     234
# Dramas, Independent Movies, International Movies    184
# Comedies, Dramas, International Movies              168
# Documentaries                                       136
# Name: listed_in, dtype: int64

# %%
df.listed_in.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Famous Genere')
plt.show()
